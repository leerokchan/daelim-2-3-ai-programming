# %% [markdown]
# # 3주차

# %% [markdown]
# 파이썬 로그 출력하기

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
1+9
# Out:
# 10

# %%
x = 100
print(x)
# Out:
# 100

# %% [markdown]
# 변수

# %%
age = 20
score = 80

print(age)
print(score)
print(age + score)
# Out:
# 20
# 80
# 100

# %% [markdown]
# 숫자와 문자열

# %%
name = "Lee"
year = 2026
print(name)
print(year)
print(type(name))
print(type(year))
# Out:
# Lee
# 2026
# <class 'str'>
# <class 'int'>

# %%
first = "machine" 
second = "learning" 

print(first + second)
print(first + " " + second)
# Out:
# machinelearning
# machine learning

# %%
major = "AI응용프로그래밍"

print(major)
print("수업명 : " + major)
# Out:
# AI응용프로그래밍
# 수업명 : AI응용프로그래밍

# %% [markdown]
# 리스트

# %%
 scores = [10, 20, 30, 40 ,50]
 print(scores)
 print(scores[1])
 print(len(scores))
 scores.append(60)
 print(scores)
 print(len(scores))
# Out:
# [10, 20, 30, 40, 50]
# 20
# 5
# [10, 20, 30, 40, 50, 60]
# 6

# %%
scores [5] = 100
print(scores)
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
scores = [60, 70, 80, 90, 100]
print(scores)
# Out:
# [60, 70, 80, 90, 100]

# %% [markdown]
# 반복문
